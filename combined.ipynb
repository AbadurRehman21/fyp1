# %%
import importlib
import smoke_detection
importlib.reload(smoke_detection)
import vehicle_detection
importlib.reload(vehicle_detection)
import license_plate_detection
importlib.reload(license_plate_detection)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# <module 'license_plate_detection' from 'c:\\Users\\Abad\\Desktop\\FYP\\yolo_test\\combine_2\\final_realtime\\license_plate_detection.py'>

# %%
import os
import cv2
import time
import csv
from collections import Counter
from ultralytics import YOLO
import easyocr

# Import existing functions and counters
from license_plate_detection import process_license_plate_frame, license_plate_counts
from smoke_detection import detect_smoke  # assume this function works on any input image (cropped or full)
from vehicle_detection import detect_vehicle

# --- Paths for Output ---
output_dir = r"./output"
os.makedirs(output_dir, exist_ok=True)
csv_file_path = os.path.join(output_dir, "detected_plates.csv")

# --- Track plates saved this session ---
saved_plates_session = set()

def save_plate_csv(plate_text, extra_info="SmokingVehicle"):
    if plate_text in saved_plates_session:
        return

    saved_plates_session.add(plate_text)
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    row = [timestamp, plate_text, extra_info]

    file_exists = os.path.isfile(csv_file_path)
    with open(csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)
        if not file_exists:
            writer.writerow(["DateTime", "LicensePlate", "ExtraInfo"])
        writer.writerow(row)
    print(f"Saved new license plate to CSV: {plate_text}")

def process_frame_strategy(frame):
    """
    Process a frame using a step-by-step strategy:
      1. Detect vehicles.
      2. For each vehicle, crop the region and run smoke detection.
      3. If smoke is confirmed, run license plate detection on that vehicle region.
      4. Annotate the full frame with the "smoking vehicle" info and save the license plate to CSV.
    
    Returns:
        Annotated frame.
    """
    output_frame = frame.copy()

    # Detect vehicles in the full frame
    vehicle_detections = detect_vehicle(frame)
    
    # Iterate over each detected vehicle
    for det in vehicle_detections:
        box = det["box"]  # [x1, y1, x2, y2]
        # Crop the region corresponding to the vehicle
        x1, y1, x2, y2 = box
        vehicle_roi = frame[y1:y2, x1:x2]
        
        # Safety check: if the ROI is empty, skip
        if vehicle_roi.size == 0:
            continue
        
        # Run smoke detection on the cropped vehicle ROI.
        # (Assuming detect_smoke can be run on any image; if it returns (smoke_detected, processed_image),
        # adapt accordingly. Here we assume it returns a boolean and a processed image.)
        smoke_detected, _ = detect_smoke(vehicle_roi)
        
        # If the vehicle region shows smoke, run license plate detection on the same region.
        if smoke_detected:
            # Option 1: Run license plate detection on the vehicle ROI.
            lp_roi = process_license_plate_frame(vehicle_roi.copy())
            # Optionally, if process_license_plate_frame returns an annotated image, you could extract
            # the license plate string from the global license_plate_counts (if that's how your module works)
            if license_plate_counts:
                most_common_plate = license_plate_counts.most_common(1)[0][0]
                # Save the license plate to CSV (only once per session)
                save_plate_csv(most_common_plate)
                # Annotate the full frame: Draw the bounding box in red and label it.
                cv2.rectangle(output_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(output_frame, f"vehicle (smoke) - Plate: {most_common_plate}", 
                            (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
            else:
                # If no plate is detected, at least label the vehicle as smoking.
                cv2.rectangle(output_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(output_frame, "vehicle (smoke)", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        else:
            # For vehicles without smoke, you might want to annotate them differently (optional)
            cv2.rectangle(output_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(output_frame, "vehicle", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    return output_frame

def run_detection(source=0):
    """
    Runs the combined strategy on either:
      - Webcam (source=0)
      - Video file (source="video.mp4")
    Saves the resulting video to ./output/predicted_output.avi
    """
    # Clear global counters and session data
    license_plate_counts.clear()
    saved_plates_session.clear()

    cap = cv2.VideoCapture(source)
    if not cap.isOpened():
        print(f"Error: Could not open source: {source}")
        return

    # --- Setup VideoWriter ---
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0 or fps is None:
        fps = 25

# Find next available filename
    i = 1
    while True:
        output_path = os.path.join(output_dir, f"predicted_output{i}.avi")
        if not os.path.exists(output_path):
            break
        i += 1

    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    print(f"Saving output video to: {output_path}")


    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or error reading frame.")
            break

        processed_frame = process_frame_strategy(frame)
        out.write(processed_frame)
        cv2.imshow("Vehicle with Confirmed Smoke Detection", processed_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()


def main():
    # Use 0 for real-time camera, or provide a path like 'input_video.mp4'
    # Example usage:
    # run_detection(0)  # real-time
    run_detection("input/smoke.mp4")  # video file

if __name__ == "__main__":
    main()
# Out:
# Saving output video to: ./output\predicted_output22.avi
#
# 0: 640x480 1 car, 272.2ms
# Speed: 0.0ms preprocess, 272.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 186.1ms
# Speed: 0.0ms preprocess, 186.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 163.3ms
# Speed: 2.0ms preprocess, 163.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 186.8ms
# Speed: 0.0ms preprocess, 186.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 179.4ms
# Speed: 0.0ms preprocess, 179.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 233.6ms
# Speed: 0.0ms preprocess, 233.6ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 179.3ms
# Speed: 4.3ms preprocess, 179.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 218.7ms
# Speed: 11.8ms preprocess, 218.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 195.6ms
# Speed: 0.0ms preprocess, 195.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 184.6ms
# Speed: 3.6ms preprocess, 184.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 175.1ms
# Speed: 0.0ms preprocess, 175.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 217.4ms
# Speed: 0.0ms preprocess, 217.4ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 183.5ms
# Speed: 0.0ms preprocess, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 199.1ms
# Speed: 0.0ms preprocess, 199.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 136.5ms
# Speed: 5.3ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 193.7ms
# Speed: 6.5ms preprocess, 193.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 198.2ms
# Speed: 0.0ms preprocess, 198.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 180.0ms
# Speed: 0.0ms preprocess, 180.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 217.7ms
# Speed: 0.0ms preprocess, 217.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 250.9ms
# Speed: 1.6ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 249.6ms
# Speed: 5.6ms preprocess, 249.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 260.9ms
# Speed: 0.0ms preprocess, 260.9ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 255.4ms
# Speed: 0.0ms preprocess, 255.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 216.8ms
# Speed: 0.0ms preprocess, 216.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 166.8ms
# Speed: 0.0ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 232.7ms
# Speed: 0.0ms preprocess, 232.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 183.8ms
# Speed: 3.9ms preprocess, 183.8ms inference, 11.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 148.0ms
# Speed: 2.9ms preprocess, 148.0ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 216.3ms
# Speed: 0.0ms preprocess, 216.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 216.4ms
# Speed: 2.1ms preprocess, 216.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 219.1ms
# Speed: 5.3ms preprocess, 219.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 212.1ms
# Speed: 0.0ms preprocess, 212.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 190.3ms
# Speed: 0.0ms preprocess, 190.3ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 206.7ms
# Speed: 5.4ms preprocess, 206.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 156.2ms
# Speed: 0.0ms preprocess, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 181.8ms
# Speed: 0.0ms preprocess, 181.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 233.0ms
# Speed: 0.0ms preprocess, 233.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 173.1ms
# Speed: 0.0ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 232.7ms
# Speed: 0.0ms preprocess, 232.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 228.4ms
# Speed: 1.2ms preprocess, 228.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 206.7ms
# Speed: 0.0ms preprocess, 206.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 203.8ms
# Speed: 0.0ms preprocess, 203.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 183.3ms
# Speed: 0.0ms preprocess, 183.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 172.1ms
# Speed: 0.0ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 185.0ms
# Speed: 0.0ms preprocess, 185.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 188.0ms
# Speed: 0.0ms preprocess, 188.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 233.7ms
# Speed: 0.0ms preprocess, 233.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 209.7ms
# Speed: 0.0ms preprocess, 209.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 207.5ms
# Speed: 0.0ms preprocess, 207.5ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 233.3ms
# Speed: 0.4ms preprocess, 233.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 226.6ms
# Speed: 1.0ms preprocess, 226.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 202.2ms
# Speed: 0.0ms preprocess, 202.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 199.0ms
# Speed: 0.0ms preprocess, 199.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 186.0ms
# Speed: 5.8ms preprocess, 186.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 244.8ms
# Speed: 0.0ms preprocess, 244.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 249.2ms
# Speed: 0.0ms preprocess, 249.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 185.0ms
# Speed: 6.0ms preprocess, 185.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 181.1ms
# Speed: 3.9ms preprocess, 181.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 161.1ms
# Speed: 0.0ms preprocess, 161.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 167.8ms
# Speed: 5.0ms preprocess, 167.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 171.8ms
# Speed: 0.0ms preprocess, 171.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 165.5ms
# Speed: 5.4ms preprocess, 165.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 184.2ms
# Speed: 0.0ms preprocess, 184.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 160.8ms
# Speed: 0.0ms preprocess, 160.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 183.2ms
# Speed: 0.0ms preprocess, 183.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 158.4ms
# Speed: 0.0ms preprocess, 158.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 167.4ms
# Speed: 0.0ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 188.4ms
# Speed: 0.0ms preprocess, 188.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 229.6ms
# Speed: 4.2ms preprocess, 229.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 178.0ms
# Speed: 0.0ms preprocess, 178.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 243.4ms
# Speed: 0.7ms preprocess, 243.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 187.8ms
# Speed: 0.0ms preprocess, 187.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 216.3ms
# Speed: 0.0ms preprocess, 216.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 193.3ms
# Speed: 0.0ms preprocess, 193.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 222.4ms
# Speed: 3.1ms preprocess, 222.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 149.7ms
# Speed: 5.4ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 266.3ms
# Speed: 0.0ms preprocess, 266.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 124.3ms
# Speed: 2.7ms preprocess, 124.3ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
# Saved new license plate to CSV: LATLIN
#
# 0: 640x480 1 car, 167.8ms
# Speed: 3.2ms preprocess, 167.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 75.5ms
# Speed: 0.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 164.1ms
# Speed: 5.1ms preprocess, 164.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 90.9ms
# Speed: 0.0ms preprocess, 90.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 216.4ms
# Speed: 0.0ms preprocess, 216.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 93.9ms
# Speed: 0.0ms preprocess, 93.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 186.8ms
# Speed: 5.5ms preprocess, 186.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 215.7ms
# Speed: 0.0ms preprocess, 215.7ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 79.7ms
# Speed: 4.6ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 189.8ms
# Speed: 0.0ms preprocess, 189.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 93.0ms
# Speed: 0.0ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 167.1ms
# Speed: 0.7ms preprocess, 167.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 12.8ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 211.2ms
# Speed: 5.4ms preprocess, 211.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 72.3ms
# Speed: 0.0ms preprocess, 72.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 1 cat, 166.6ms
# Speed: 0.0ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 75.5ms
# Speed: 0.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 149.8ms
# Speed: 4.8ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 163.7ms
# Speed: 2.5ms preprocess, 163.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 1 cat, 174.0ms
# Speed: 2.6ms preprocess, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 89.0ms
# Speed: 0.0ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLI
#
# 0: 640x480 1 car, 198.3ms
# Speed: 0.0ms preprocess, 198.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIIN
#
# 0: 640x480 1 car, 177.2ms
# Speed: 4.9ms preprocess, 177.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 83.4ms
# Speed: 0.0ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 215.5ms
# Speed: 1.1ms preprocess, 215.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 98.3ms
# Speed: 0.0ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 257.8ms
# Speed: 0.0ms preprocess, 257.8ms inference, 16.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 93.0ms
# Speed: 0.0ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 192.5ms
# Speed: 0.0ms preprocess, 192.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 86.1ms
# Speed: 0.0ms preprocess, 86.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 171.8ms
# Speed: 0.0ms preprocess, 171.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 95.6ms
# Speed: 0.0ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 188.2ms
# Speed: 2.8ms preprocess, 188.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 82.9ms
# Speed: 0.0ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 83.9ms
# Speed: 0.0ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 174.2ms
# Speed: 0.0ms preprocess, 174.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 2 ANPRs, 71.3ms
# Speed: 15.8ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
# Detected License Plate:
#
# 0: 640x480 1 car, 217.8ms
# Speed: 2.0ms preprocess, 217.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 73.6ms
# Speed: 0.0ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 167.5ms
# Speed: 3.4ms preprocess, 167.5ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 83.4ms
# Speed: 0.0ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIN
# Saved new license plate to CSV: FLATLIN
#
# 0: 640x480 1 car, 175.4ms
# Speed: 0.0ms preprocess, 175.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 198.1ms
# Speed: 7.1ms preprocess, 198.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 78.3ms
# Speed: 5.8ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 167.0ms
# Speed: 5.7ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 ANPR, 85.8ms
# Speed: 0.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 181.7ms
# Speed: 0.0ms preprocess, 181.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 ANPR, 74.5ms
# Speed: 6.9ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 162.9ms
# Speed: 3.4ms preprocess, 162.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 103.5ms
# Speed: 0.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 176.9ms
# Speed: 0.0ms preprocess, 176.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 67.4ms
# Speed: 9.5ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 189.0ms
# Speed: 0.0ms preprocess, 189.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 172.6ms
# Speed: 0.0ms preprocess, 172.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 ANPR, 79.2ms
# Speed: 15.8ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 158.3ms
# Speed: 0.0ms preprocess, 158.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 ANPR, 99.7ms
# Speed: 0.0ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 201.7ms
# Speed: 0.0ms preprocess, 201.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 79.1ms
# Speed: 0.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 189.2ms
# Speed: 0.0ms preprocess, 189.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 576x640 1 ANPR, 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 186.8ms
# Speed: 0.0ms preprocess, 186.8ms inference, 11.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 4.7ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 214.0ms
# Speed: 0.0ms preprocess, 214.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 82.2ms
# Speed: 0.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 208.5ms
# Speed: 0.0ms preprocess, 208.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 162.6ms
# Speed: 0.0ms preprocess, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 78.0ms
# Speed: 0.0ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 164.7ms
# Speed: 4.7ms preprocess, 164.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 85.9ms
# Speed: 0.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 175.8ms
# Speed: 5.5ms preprocess, 175.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 79.5ms
# Speed: 0.0ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 233.5ms
# Speed: 3.9ms preprocess, 233.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 221.2ms
# Speed: 0.0ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 95.1ms
# Speed: 0.0ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 246.5ms
# Speed: 7.1ms preprocess, 246.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 88.0ms
# Speed: 3.0ms preprocess, 88.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 211.0ms
# Speed: 5.7ms preprocess, 211.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 80.4ms
# Speed: 0.0ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 283.6ms
# Speed: 7.6ms preprocess, 283.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 71.0ms
# Speed: 0.0ms preprocess, 71.0ms inference, 8.5ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 206.5ms
# Speed: 0.0ms preprocess, 206.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 87.0ms
# Speed: 0.0ms preprocess, 87.0ms inference, 9.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 203.2ms
# Speed: 0.0ms preprocess, 203.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 82.7ms
# Speed: 0.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 232.9ms
# Speed: 4.4ms preprocess, 232.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 103.0ms
# Speed: 16.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 191.3ms
# Speed: 0.0ms preprocess, 191.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 75.6ms
# Speed: 0.0ms preprocess, 75.6ms inference, 12.7ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 157.6ms
# Speed: 3.6ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 174.1ms
# Speed: 6.2ms preprocess, 174.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 74.8ms
# Speed: 0.0ms preprocess, 74.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 189.8ms
# Speed: 0.0ms preprocess, 189.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 91.9ms
# Speed: 0.0ms preprocess, 91.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 215.0ms
# Speed: 2.3ms preprocess, 215.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 79.5ms
# Speed: 0.0ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 144.7ms
# Speed: 5.8ms preprocess, 144.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 71.4ms
# Speed: 0.0ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 196.5ms
# Speed: 2.9ms preprocess, 196.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 15.3ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 185.4ms
# Speed: 0.0ms preprocess, 185.4ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 82.9ms
# Speed: 6.5ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 221.9ms
# Speed: 0.0ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 168.6ms
# Speed: 0.0ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 71.1ms
# Speed: 0.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 241.2ms
# Speed: 2.9ms preprocess, 241.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 248.4ms
# Speed: 0.0ms preprocess, 248.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 71.7ms
# Speed: 7.7ms preprocess, 71.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: FFLATLIN
#
# 0: 640x480 1 car, 181.3ms
# Speed: 0.0ms preprocess, 181.3ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 1 ANPR, 80.9ms
# Speed: 6.7ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 215.7ms
# Speed: 0.0ms preprocess, 215.7ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 512x640 1 ANPR, 87.3ms
# Speed: 0.0ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# Detected License Plate: LATLIN

# %% [markdown]
# method #2 (license palte on full frame)

# %%
import os
import cv2
import time
import csv
from collections import Counter
from ultralytics import YOLO
import easyocr

# Import license plate and smoke detection functions and global counters.
from license_plate_detection import process_license_plate_frame, license_plate_counts
from smoke_detection import detect_smoke  # Assume detect_smoke(frame) returns a tuple: (smoke_detected, processed_smoke_frame)
from vehicle_detection import detect_vehicle

# --- Paths for Output ---
output_dir = r"./output"
os.makedirs(output_dir, exist_ok=True)
csv_file_path = os.path.join(output_dir, "detected_plates.csv")

# --- Track plates saved this session ---
saved_plates_session = set()

def save_plate_csv(plate_text, extra_info="SmokingVehicle"):
    if plate_text in saved_plates_session:
        return

    saved_plates_session.add(plate_text)
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    row = [timestamp, plate_text, extra_info]

    file_exists = os.path.isfile(csv_file_path)
    with open(csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)
        if not file_exists:
            writer.writerow(["DateTime", "LicensePlate", "ExtraInfo"])
        writer.writerow(row)
    print(f"Saved new license plate to CSV: {plate_text}")

def compute_iou(box1, box2):
    """
    Compute the Intersection over Union (IoU) of two bounding boxes.
    Each box is defined as [x1, y1, x2, y2].
    """
    x1_inter = max(box1[0], box2[0])
    y1_inter = max(box1[1], box2[1])
    x2_inter = min(box1[2], box2[2])
    y2_inter = min(box1[3], box2[3])
    
    inter_width = max(0, x2_inter - x1_inter)
    inter_height = max(0, y2_inter - y1_inter)
    inter_area = inter_width * inter_height

    box1_area = (box1[2]-box1[0]) * (box1[3]-box1[1])
    box2_area = (box2[2]-box2[0]) * (box2[3]-box2[1])
    
    union_area = box1_area + box2_area - inter_area
    if union_area == 0:
        return 0
    return inter_area / union_area

def detect_license_plate(frame):
    """
    Run license plate detection on the full frame.
    This function is assumed to return a list of detections.
    Each detection is a dictionary with keys:
         "box": [x1, y1, x2, y2] bounding box,
         "text": recognized license plate text.
         
    Here we call process_license_plate_frame to draw and update the global counter,
    but then we assume that the license_plate_counts (or another mechanism) provides the detections.
    For demonstration purposes, we assume this function returns an empty list
    if you haven't implemented a proper LP detector.
    
    Replace this placeholder with your actual license plate detection code.
    """
    # You might already have code that shows LP annotations on the frame.
    # For demonstration, call the existing function:
    _ = process_license_plate_frame(frame.copy())
    # If your module stores detections in a global variable (e.g., license_plate_counts),
    # you could convert that into a list of detection dictionaries.
    # As a placeholder, we return an empty list.
    return []  # Replace with actual return value if available

def process_frame_strategy(frame):
    """
    This function:
      1. Runs full-frame license plate detection (draws green boxes + text).
      2. Runs vehicle detection to get vehicle boxes.
      3. For each vehicle, run smoke detection on a cropped ROI.
      4. If smoke is confirmed, highlight the vehicle in red, otherwise green.
      5. Optionally match the vehicle with the plate if needed via IoU, etc.
    """
    # 1) License Plate Detection (full frame)
    #    The function returns an annotated frame with bounding boxes in green + text.
    lp_annotated_frame = process_license_plate_frame(frame.copy())
    
    # 2) Vehicle Detection
    vehicle_detections = detect_vehicle(frame)

    # Prepare final annotation frame by copying the license plate annotated version
    # so that we keep the green LP bounding boxes always visible.
    output_frame = lp_annotated_frame.copy()

    # 3) For each vehicle, do smoke detection
    for veh in vehicle_detections:
        vbox = veh["box"]  # [x1, y1, x2, y2]

        # Crop vehicle ROI
        vehicle_roi = frame[vbox[1]:vbox[3], vbox[0]:vbox[2]]
        if vehicle_roi.size == 0:
            continue

        # Suppose detect_smoke returns a boolean
        smoke_found, _ = detect_smoke(vehicle_roi)

        # 4) Annotate the vehicle box
        if smoke_found:
            color = (0, 0, 255)  # red
            label = "vehicle (smoke)"
        else:
            color = (0, 255, 0)  # green
            label = "vehicle"

        cv2.rectangle(output_frame, (vbox[0], vbox[1]), (vbox[2], vbox[3]), color, 2)
        cv2.putText(output_frame, label, (vbox[0], vbox[1] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    return output_frame


def run_detection(source=0):
    """
    Runs the detection strategy on either:
      - A Webcam (source=0)
      - A Video file (source="path/to/video.mp4")
    Saves the resulting output video to a uniquely named file.
    """
    # Clear global counters and session data.
    license_plate_counts.clear()
    saved_plates_session.clear()
    
    cap = cv2.VideoCapture(source)
    if not cap.isOpened():
        print(f"Error: Could not open source: {source}")
        return
    
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0 or fps is None:
        fps = 25

    # Generate a unique output filename.
    i = 1
    while True:
        output_path = os.path.join(output_dir, f"predicted_output{i}.avi")
        if not os.path.exists(output_path):
            break
        i += 1
    
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    print(f"Saving output video to: {output_path}")
    
    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or error reading frame.")
            break
        
        processed_frame = process_frame_strategy(frame)
        out.write(processed_frame)
        cv2.imshow("Advanced Vehicle-Smoke-Plate Detection", processed_frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()

def main():
    # Use 0 for webcam feed or provide the path to a video file.
    run_detection("input/smoke.mp4")  # Replace with your input source

if __name__ == "__main__":
    main()
# Out:
# Saving output video to: ./output\predicted_output23.avi
#
# 0: 640x480 1 ANPR, 134.7ms
# Speed: 0.0ms preprocess, 134.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ELATLIN
#
# 0: 640x480 1 car, 204.8ms
# Speed: 0.0ms preprocess, 204.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 94.9ms
# Speed: 11.4ms preprocess, 94.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 car, 167.5ms
# Speed: 10.8ms preprocess, 167.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 87.6ms
# Speed: 12.1ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 148.9ms
# Speed: 0.0ms preprocess, 148.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 78.7ms
# Speed: 0.0ms preprocess, 78.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 171.9ms
# Speed: 0.0ms preprocess, 171.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 6.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 170.8ms
# Speed: 0.0ms preprocess, 170.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 85.2ms
# Speed: 0.0ms preprocess, 85.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATIN
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.8ms
# Speed: 5.4ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 162.9ms
# Speed: 0.0ms preprocess, 162.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 144.4ms
# Speed: 8.8ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 75.5ms
# Speed: 4.5ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 162.6ms
# Speed: 0.0ms preprocess, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 61.7ms
# Speed: 2.5ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.5ms
# Speed: 12.0ms preprocess, 149.5ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.9ms
# Speed: 0.0ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 153.0ms
# Speed: 0.0ms preprocess, 153.0ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 4.4ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 166.9ms
# Speed: 0.0ms preprocess, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 145.6ms
# Speed: 4.3ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.4ms
# Speed: 0.0ms preprocess, 70.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 166.9ms
# Speed: 0.0ms preprocess, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.7ms
# Speed: 0.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.7ms
# Speed: 3.4ms preprocess, 150.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.3ms
# Speed: 0.0ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.6ms
# Speed: 5.7ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 154.7ms
# Speed: 9.5ms preprocess, 154.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.9ms
# Speed: 0.0ms preprocess, 77.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 167.2ms
# Speed: 5.2ms preprocess, 167.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.0ms
# Speed: 0.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.5ms
# Speed: 0.0ms preprocess, 150.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.7ms
# Speed: 0.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 100.2ms
# Speed: 4.4ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 172.6ms
# Speed: 14.3ms preprocess, 172.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.3ms
# Speed: 4.7ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 149.5ms
# Speed: 0.0ms preprocess, 149.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.9ms
# Speed: 3.5ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 164.6ms
# Speed: 0.0ms preprocess, 164.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.1ms
# Speed: 0.0ms preprocess, 70.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.4ms
# Speed: 4.3ms preprocess, 150.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 155.1ms
# Speed: 0.0ms preprocess, 155.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.5ms
# Speed: 5.9ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.2ms
# Speed: 0.0ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 148.4ms
# Speed: 0.0ms preprocess, 148.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 137.7ms
# Speed: 0.0ms preprocess, 137.7ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 4.2ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 146.6ms
# Speed: 0.0ms preprocess, 146.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 101.0ms
# Speed: 2.2ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 169.8ms
# Speed: 10.2ms preprocess, 169.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.5ms
# Speed: 4.9ms preprocess, 66.5ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 175.6ms
# Speed: 0.0ms preprocess, 175.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 12.8ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.6ms
# Speed: 14.2ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 85.1ms
# Speed: 4.6ms preprocess, 85.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 159.8ms
# Speed: 0.0ms preprocess, 159.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.5ms
# Speed: 5.8ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 171.5ms
# Speed: 0.0ms preprocess, 171.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.7ms
# Speed: 5.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 170.6ms
# Speed: 0.0ms preprocess, 170.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 5.3ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.3ms
# Speed: 4.7ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.1ms
# Speed: 0.0ms preprocess, 77.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 166.7ms
# Speed: 0.0ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.2ms
# Speed: 0.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 155.4ms
# Speed: 0.0ms preprocess, 155.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.0ms
# Speed: 5.6ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 160.2ms
# Speed: 0.0ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.1ms
# Speed: 0.0ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.2ms
# Speed: 0.0ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.6ms
# Speed: 0.0ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 5.2ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 136.6ms
# Speed: 0.0ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.6ms
# Speed: 5.3ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 145.0ms
# Speed: 0.0ms preprocess, 145.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.6ms
# Speed: 6.8ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 185.0ms
# Speed: 11.2ms preprocess, 185.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.1ms
# Speed: 0.0ms preprocess, 82.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 151.1ms
# Speed: 0.0ms preprocess, 151.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.6ms
# Speed: 0.0ms preprocess, 70.6ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 144.4ms
# Speed: 1.5ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.5ms
# Speed: 0.0ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 152.6ms
# Speed: 13.7ms preprocess, 152.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 81.7ms
# Speed: 0.0ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.7ms
# Speed: 1.3ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 99.7ms
# Speed: 0.8ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FFLATLIN
#
# 0: 640x480 1 car, 153.7ms
# Speed: 0.0ms preprocess, 153.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.6ms
# Speed: 0.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLHTLIN
#
# 0: 640x480 1 car, 150.6ms
# Speed: 0.0ms preprocess, 150.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 84.1ms
# Speed: 5.3ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLHTLIN
#
# 0: 640x480 1 car, 184.4ms
# Speed: 2.8ms preprocess, 184.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.0ms
# Speed: 4.8ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.4ms
# Speed: 0.0ms preprocess, 149.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.8ms
# Speed: 0.0ms preprocess, 77.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.0ms
# Speed: 0.5ms preprocess, 66.0ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 167.1ms
# Speed: 0.0ms preprocess, 167.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.6ms
# Speed: 4.2ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 147.0ms
# Speed: 0.0ms preprocess, 147.0ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 65.5ms
# Speed: 1.7ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 146.0ms
# Speed: 0.0ms preprocess, 146.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.8ms
# Speed: 4.4ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 171.0ms
# Speed: 0.0ms preprocess, 171.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.8ms
# Speed: 3.9ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 car, 167.1ms
# Speed: 0.0ms preprocess, 167.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 4.2ms preprocess, 66.7ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 229.2ms
# Speed: 0.0ms preprocess, 229.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 90.5ms
# Speed: 0.0ms preprocess, 90.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 200.8ms
# Speed: 0.0ms preprocess, 200.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 149.8ms
# Speed: 0.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.9ms
# Speed: 0.0ms preprocess, 69.9ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 107.0ms
# Speed: 0.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 167.1ms
# Speed: 0.0ms preprocess, 167.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 78.4ms
# Speed: 0.0ms preprocess, 78.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.8ms
# Speed: 0.0ms preprocess, 150.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.5ms
# Speed: 5.3ms preprocess, 69.5ms inference, 12.1ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 175.0ms
# Speed: 0.0ms preprocess, 175.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 163.2ms
# Speed: 0.0ms preprocess, 163.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.5ms
# Speed: 2.5ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 161.8ms
# Speed: 0.0ms preprocess, 161.8ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.9ms
# Speed: 0.0ms preprocess, 72.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 159.2ms
# Speed: 0.0ms preprocess, 159.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.8ms
# Speed: 4.9ms preprocess, 66.8ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 150.8ms
# Speed: 0.0ms preprocess, 150.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 134.9ms
# Speed: 0.0ms preprocess, 134.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.3ms
# Speed: 4.5ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 158.6ms
# Speed: 0.0ms preprocess, 158.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.7ms
# Speed: 0.0ms preprocess, 73.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 145.4ms
# Speed: 5.3ms preprocess, 145.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 75.3ms
# Speed: 4.4ms preprocess, 75.3ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 165.9ms
# Speed: 0.8ms preprocess, 165.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.7ms
# Speed: 0.0ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 car, 183.4ms
# Speed: 0.0ms preprocess, 183.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.7ms
# Speed: 4.1ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 143.0ms
# Speed: 0.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.5ms
# Speed: 0.0ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 177.7ms
# Speed: 4.8ms preprocess, 177.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 75.0ms
# Speed: 4.4ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 163.1ms
# Speed: 1.1ms preprocess, 163.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.7ms
# Speed: 0.0ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 138.9ms
# Speed: 11.4ms preprocess, 138.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.0ms
# Speed: 0.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 159.9ms
# Speed: 0.0ms preprocess, 159.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.1ms
# Speed: 0.0ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLTLIN
#
# 0: 640x480 1 car, 141.4ms
# Speed: 0.0ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.3ms
# Speed: 4.6ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 159.2ms
# Speed: 0.0ms preprocess, 159.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.3ms
# Speed: 5.5ms preprocess, 67.3ms inference, 12.5ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 86.0ms
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 167.5ms
# Speed: 0.0ms preprocess, 167.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.9ms
# Speed: 0.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 147.5ms
# Speed: 0.0ms preprocess, 147.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 178.6ms
# Speed: 0.0ms preprocess, 178.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.1ms
# Speed: 4.2ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 164.4ms
# Speed: 0.0ms preprocess, 164.4ms inference, 12.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.3ms
# Speed: 0.0ms preprocess, 82.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.7ms
# Speed: 0.0ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 75.2ms
# Speed: 0.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 144.7ms
# Speed: 11.4ms preprocess, 144.7ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.7ms
# Speed: 5.0ms preprocess, 67.7ms inference, 12.6ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 160.0ms
# Speed: 0.0ms preprocess, 160.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 4.3ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 174.3ms
# Speed: 0.0ms preprocess, 174.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 63.6ms
# Speed: 3.2ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.3ms
# Speed: 0.0ms preprocess, 149.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.9ms
# Speed: 2.9ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.2ms
# Speed: 0.0ms preprocess, 149.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 123.5ms
# Speed: 6.1ms preprocess, 123.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 169.1ms
# Speed: 5.1ms preprocess, 169.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 152.8ms
# Speed: 14.2ms preprocess, 152.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.1ms
# Speed: 0.9ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 167.9ms
# Speed: 0.0ms preprocess, 167.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.0ms
# Speed: 0.8ms preprocess, 67.0ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 145.6ms
# Speed: 0.0ms preprocess, 145.6ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 94.2ms
# Speed: 5.6ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.0ms
# Speed: 0.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.3ms
# Speed: 0.0ms preprocess, 73.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 147.0ms
# Speed: 5.3ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 82.9ms
# Speed: 5.6ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 150.2ms
# Speed: 9.3ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 80.3ms
# Speed: 4.5ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 154.0ms
# Speed: 12.6ms preprocess, 154.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 149.0ms
# Speed: 11.6ms preprocess, 149.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.4ms
# Speed: 0.0ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 150.0ms
# Speed: 0.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.8ms
# Speed: 6.7ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 161.0ms
# Speed: 0.0ms preprocess, 161.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
import os
import cv2
import time
import csv
from collections import Counter
from ultralytics import YOLO

# Import license plate and smoke detection functions and global counters.
from license_plate_detection import process_license_plate_frame, license_plate_counts
from smoke_detection import detect_smoke  # Expected to return (smoke_detected, processed_smoke_frame)
from vehicle_detection import detect_vehicle  # Returns list of dicts with keys "box", "confidence", "class"

# --- Paths for Output ---
output_dir = r"./output"
os.makedirs(output_dir, exist_ok=True)
csv_file_path = os.path.join(output_dir, "detected_plates.csv")

# --- Paths for Output ---
output_dir = r"./output"
os.makedirs(output_dir, exist_ok=True)
csv_file_path = os.path.join(output_dir, "detected_plates.csv")

# --- Track plates saved this session ---
saved_plates_session = set()

def save_plate_csv(plate_text, extra_info="SmokingVehicle"):
    if plate_text in saved_plates_session:
        return

    saved_plates_session.add(plate_text)
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    row = [timestamp, plate_text, extra_info]

    file_exists = os.path.isfile(csv_file_path)
    with open(csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)
        if not file_exists:
            writer.writerow(["DateTime", "LicensePlate", "ExtraInfo"])
        writer.writerow(row)
    print(f"Saved new license plate to CSV: {plate_text}")


def compute_iou(box1, box2):
    """
    Compute the Intersection over Union (IoU) of two bounding boxes.
    Each box is defined as [x1, y1, x2, y2].
    """
    x1_inter = max(box1[0], box2[0])
    y1_inter = max(box1[1], box2[1])
    x2_inter = min(box1[2], box2[2])
    y2_inter = min(box1[3], box2[3])
    
    inter_width = max(0, x2_inter - x1_inter)
    inter_height = max(0, y2_inter - y1_inter)
    inter_area = inter_width * inter_height

    box1_area = (box1[2]-box1[0]) * (box1[3]-box1[1])
    box2_area = (box2[2]-box2[0]) * (box2[3]-box2[1])
    
    union_area = box1_area + box2_area - inter_area
    if union_area == 0:
        return 0
    return inter_area / union_area

def detect_license_plate(frame):
    """
    Run license plate detection on the full frame.
    This function calls process_license_plate_frame (which draws annotations and updates a global counter)
    and is intended to return a list of detections in the format:
    [{"box": [x1, y1, x2, y2], "text": "ABC123"}, ...].
    Currently, it returns an empty list as a placeholder.
    """
    _ = process_license_plate_frame(frame.copy())
    # TODO: Update this function to extract and return structured detection results.
    return []  # Placeholder return

def process_frame_combined(frame):
    """
    Processes a frame by running:
      1. Full-frame license plate detection.
      2. Vehicle detection.
      3. For each detected vehicle, running smoke detection on its cropped ROI.
      4. Matching the vehicle bounding box with global license plate detections (using IoU).
      5. Annotating the frame with:
           - License plate boxes (blue) from global detection.
           - Vehicle bounding boxes (red if smoke detected, green otherwise).
           - If a smoking vehicle has a matched license plate, overlay the plate text and save it to CSV.
    """
    # Step 1: Global license plate detection
    global_lp_detections = detect_license_plate(frame)  # Expected format: [{"box": [...], "text": ...}, ...]
    
    # Step 2: Vehicle detection
    vehicle_detections = detect_vehicle(frame)
    
    # Get a version of the frame with LP annotations (so LP boxes are always visible)
    lp_annotated_frame = process_license_plate_frame(frame.copy())
    output_frame = lp_annotated_frame.copy()
    
    iou_threshold = 0.3
    
    for veh in vehicle_detections:
        vbox = veh["box"]  # [x1, y1, x2, y2]
        vehicle_roi = frame[vbox[1]:vbox[3], vbox[0]:vbox[2]]
        if vehicle_roi.size == 0:
            continue
        
        smoke_found, _ = detect_smoke(vehicle_roi)
        
        if smoke_found:
            color = (0, 0, 255)  # red for smoking vehicle
            label = "vehicle (smoke)"
            lp_matched = False
            # Match vehicle box to global license plate detections using IoU.
            for lp in global_lp_detections:
                if compute_iou(vbox, lp["box"]) >= iou_threshold:
                    lp_text = lp["text"]
                    cv2.putText(output_frame, f"vehicle (smoke) - Plate: {lp_text}",
                                (vbox[0], vbox[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
                    save_plate_csv(lp_text)
                    lp_matched = True
                    break
            if not lp_matched:
                cv2.putText(output_frame, label, (vbox[0], vbox[1]-10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        else:
            color = (0, 255, 0)  # green for non-smoking vehicles
            label = "vehicle"
            cv2.putText(output_frame, label, (vbox[0], vbox[1]-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
        
        cv2.rectangle(output_frame, (vbox[0], vbox[1]), (vbox[2], vbox[3]), color, 2)
    
    # Step 5: Draw the global license plate detections (blue boxes) so they are always visible.
    for lp in global_lp_detections:
        lp_box = lp["box"]
        lp_text = lp["text"]
        cv2.rectangle(output_frame, (lp_box[0], lp_box[1]), (lp_box[2], lp_box[3]), (255, 0, 0), 2)
        cv2.putText(output_frame, lp_text, (lp_box[0], lp_box[1]-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)
    
    return output_frame

def run_detection(source=0):
    """
    Runs detection strategy on a webcam (source=0) or video file.
    Saves the annotated video to a uniquely named file.
    """
    # Clear counters/session data.
    license_plate_counts.clear()
    saved_plates_session.clear()
    
    cap = cv2.VideoCapture(source)
    if not cap.isOpened():
        print(f"Error: Could not open source: {source}")
        return
    
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0 or fps is None:
        fps = 25
    
    i = 1
    while True:
        output_path = os.path.join(output_dir, f"predicted_output{i}.avi")
        if not os.path.exists(output_path):
            break
        i += 1
    
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    print(f"Saving output video to: {output_path}")
    
    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or error reading frame.")
            break
        
        processed_frame = process_frame_combined(frame)
        out.write(processed_frame)
        cv2.imshow("Advanced Vehicle-Smoke-LP Detection", processed_frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()

def main():
    # Use 0 for webcam feed or a path for a video file.
    run_detection("input/smoke.mp4")  # Update with your input source

if __name__ == "__main__":
    main()
# Out:
# Saving output video to: ./output\predicted_output17.avi
#
# 0: 640x480 1 ANPR, 98.7ms
# Speed: 2.0ms preprocess, 98.7ms inference, 12.6ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ELATLIN
#
# 0: 640x480 1 car, 160.6ms
# Speed: 0.0ms preprocess, 160.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ELATLIN
#
# 0: 640x480 1 ANPR, 75.4ms
# Speed: 0.0ms preprocess, 75.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 car, 180.3ms
# Speed: 0.0ms preprocess, 180.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 ANPR, 66.6ms
# Speed: 5.3ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.7ms
# Speed: 0.0ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.4ms
# Speed: 0.0ms preprocess, 69.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 77.6ms
# Speed: 0.0ms preprocess, 77.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 187.1ms
# Speed: 0.0ms preprocess, 187.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.9ms
# Speed: 0.0ms preprocess, 77.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 4.5ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 162.3ms
# Speed: 2.5ms preprocess, 162.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATIN
#
# 0: 640x480 1 car, 186.9ms
# Speed: 0.0ms preprocess, 186.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 96.4ms
# Speed: 0.0ms preprocess, 96.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATIN
#
# 0: 640x480 1 ANPR, 76.4ms
# Speed: 0.0ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 186.5ms
# Speed: 13.5ms preprocess, 186.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 79.5ms
# Speed: 12.6ms preprocess, 79.5ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 205.9ms
# Speed: 0.0ms preprocess, 205.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 98.5ms
# Speed: 12.1ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 84.9ms
# Speed: 0.0ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 158.6ms
# Speed: 2.7ms preprocess, 158.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 79.0ms
# Speed: 0.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 94.5ms
# Speed: 0.0ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 157.4ms
# Speed: 0.0ms preprocess, 157.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.1ms
# Speed: 15.8ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 194.1ms
# Speed: 0.0ms preprocess, 194.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 98.9ms
# Speed: 9.9ms preprocess, 98.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 104.6ms
# Speed: 2.6ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 174.3ms
# Speed: 0.0ms preprocess, 174.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 63.1ms
# Speed: 15.9ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 94.6ms
# Speed: 0.0ms preprocess, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 189.9ms
# Speed: 0.0ms preprocess, 189.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 79.0ms
# Speed: 16.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 ANPR, 126.1ms
# Speed: 0.0ms preprocess, 126.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 183.4ms
# Speed: 0.0ms preprocess, 183.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 78.2ms
# Speed: 16.1ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 83.7ms
# Speed: 0.0ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 166.6ms
# Speed: 0.6ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.7ms
# Speed: 0.0ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 68.2ms
# Speed: 4.8ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.4ms
# Speed: 1.4ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.3ms
# Speed: 5.0ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 87.0ms
# Speed: 0.0ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 71.1ms
# Speed: 0.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 155.6ms
# Speed: 0.0ms preprocess, 155.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.9ms
# Speed: 0.0ms preprocess, 77.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 74.3ms
# Speed: 4.7ms preprocess, 74.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.4ms
# Speed: 0.0ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 81.2ms
# Speed: 0.0ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 183.6ms
# Speed: 0.0ms preprocess, 183.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 189.7ms
# Speed: 0.0ms preprocess, 189.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.7ms
# Speed: 0.0ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 75.5ms
# Speed: 0.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 167.0ms
# Speed: 0.0ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 74.8ms
# Speed: 12.2ms preprocess, 74.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 ANPR, 72.4ms
# Speed: 5.1ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 165.7ms
# Speed: 0.0ms preprocess, 165.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.8ms
# Speed: 6.3ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 62.2ms
# Speed: 0.0ms preprocess, 62.2ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.8ms
# Speed: 2.4ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 ANPR, 81.9ms
# Speed: 0.0ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 140.3ms
# Speed: 4.0ms preprocess, 140.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 75.0ms
# Speed: 0.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.8ms
# Speed: 12.8ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 79.4ms
# Speed: 0.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 158.7ms
# Speed: 0.0ms preprocess, 158.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.3ms
# Speed: 0.0ms preprocess, 72.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 66.5ms
# Speed: 5.9ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 172.6ms
# Speed: 0.0ms preprocess, 172.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 85.7ms
# Speed: 8.8ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 157.5ms
# Speed: 9.4ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 168.8ms
# Speed: 0.0ms preprocess, 168.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.1ms
# Speed: 0.0ms preprocess, 77.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 77.4ms
# Speed: 0.0ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 171.4ms
# Speed: 1.6ms preprocess, 171.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.8ms
# Speed: 7.7ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 70.7ms
# Speed: 0.0ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 156.7ms
# Speed: 0.0ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 76.1ms
# Speed: 0.0ms preprocess, 76.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 75.3ms
# Speed: 6.0ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 166.9ms
# Speed: 0.0ms preprocess, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 78.3ms
# Speed: 0.0ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 ANPR, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.2ms
# Speed: 5.3ms preprocess, 149.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.0ms
# Speed: 0.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 73.5ms
# Speed: 0.0ms preprocess, 73.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 200.3ms
# Speed: 0.0ms preprocess, 200.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.3ms
# Speed: 2.0ms preprocess, 72.3ms inference, 13.2ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 ANPR, 73.4ms
# Speed: 0.0ms preprocess, 73.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 168.1ms
# Speed: 0.0ms preprocess, 168.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 62.8ms
# Speed: 4.5ms preprocess, 62.8ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 ANPR, 75.3ms
# Speed: 0.0ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.5ms
# Speed: 0.0ms preprocess, 166.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 90.3ms
# Speed: 10.5ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 99.3ms
# Speed: 0.0ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 161.1ms
# Speed: 3.4ms preprocess, 161.1ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 76.1ms
# Speed: 0.0ms preprocess, 76.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 154.9ms
# Speed: 0.0ms preprocess, 154.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.9ms
# Speed: 7.4ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.1ms
# Speed: 0.0ms preprocess, 72.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 66.9ms
# Speed: 5.4ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 151.1ms
# Speed: 4.3ms preprocess, 151.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.3ms
# Speed: 0.0ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 83.6ms
# Speed: 0.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 168.8ms
# Speed: 0.0ms preprocess, 168.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.1ms
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 77.0ms
# Speed: 0.0ms preprocess, 77.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 139.4ms
# Speed: 0.0ms preprocess, 139.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 78.7ms
# Speed: 4.8ms preprocess, 78.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 164.5ms
# Speed: 0.0ms preprocess, 164.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.3ms
# Speed: 0.0ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 70.2ms
# Speed: 0.0ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 147.9ms
# Speed: 2.7ms preprocess, 147.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.1ms
# Speed: 11.6ms preprocess, 71.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 71.2ms
# Speed: 5.3ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 145.8ms
# Speed: 4.5ms preprocess, 145.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 68.1ms
# Speed: 0.4ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 151.5ms
# Speed: 0.0ms preprocess, 151.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 74.8ms
# Speed: 5.0ms preprocess, 74.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 car, 167.0ms
# Speed: 0.0ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIM
#
# 0: 640x480 1 ANPR, 83.9ms
# Speed: 2.6ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 car, 153.1ms
# Speed: 7.3ms preprocess, 153.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 80.8ms
# Speed: 0.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIM
#
# 0: 640x480 1 ANPR, 82.7ms
# Speed: 7.5ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.8ms
# Speed: 0.0ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.6ms
# Speed: 15.2ms preprocess, 67.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 76.6ms
# Speed: 0.0ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 149.8ms
# Speed: 0.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 63.8ms
# Speed: 0.0ms preprocess, 63.8ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 82.7ms
# Speed: 0.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 157.2ms
# Speed: 0.0ms preprocess, 157.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.9ms
# Speed: 0.0ms preprocess, 70.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 77.9ms
# Speed: 0.0ms preprocess, 77.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FFLATLIN
#
# 0: 640x480 1 car, 151.3ms
# Speed: 15.2ms preprocess, 151.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FFLATLIN
#
# 0: 640x480 1 ANPR, 75.5ms
# Speed: 0.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLHTLIN
#
# 0: 640x480 1 car, 150.9ms
# Speed: 0.0ms preprocess, 150.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.3ms
# Speed: 14.3ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLHTLIN
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 5.2ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLHTLIN
#
# 0: 640x480 1 car, 154.4ms
# Speed: 0.0ms preprocess, 154.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 95.3ms
# Speed: 4.7ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLHTLIN
#
# 0: 640x480 1 ANPR, 87.8ms
# Speed: 0.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 146.2ms
# Speed: 7.6ms preprocess, 146.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 70.0ms
# Speed: 4.2ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 178.1ms
# Speed: 0.0ms preprocess, 178.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 130.4ms
# Speed: 0.0ms preprocess, 130.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 188.6ms
# Speed: 0.0ms preprocess, 188.6ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.1ms
# Speed: 5.2ms preprocess, 70.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 155.9ms
# Speed: 0.0ms preprocess, 155.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 70.5ms
# Speed: 5.4ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 154.7ms
# Speed: 0.0ms preprocess, 154.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.5ms
# Speed: 8.3ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 75.8ms
# Speed: 0.0ms preprocess, 75.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 168.1ms
# Speed: 0.0ms preprocess, 168.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 ANPR, 79.8ms
# Speed: 4.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 car, 181.7ms
# Speed: 0.0ms preprocess, 181.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.1ms
# Speed: 10.1ms preprocess, 73.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 ANPR, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 151.8ms
# Speed: 0.0ms preprocess, 151.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.9ms
# Speed: 0.0ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 200.4ms
# Speed: 0.0ms preprocess, 200.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 92.5ms
# Speed: 0.0ms preprocess, 92.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 83.5ms
# Speed: 0.0ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 154.1ms
# Speed: 16.0ms preprocess, 154.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.7ms
# Speed: 5.9ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 79.9ms
# Speed: 0.0ms preprocess, 79.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 156.2ms
# Speed: 0.0ms preprocess, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 ANPR, 76.7ms
# Speed: 4.4ms preprocess, 76.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.4ms
# Speed: 3.7ms preprocess, 150.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.2ms
# Speed: 15.8ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 100.2ms
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 197.5ms
# Speed: 0.0ms preprocess, 197.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 69.7ms
# Speed: 0.0ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 82.6ms
# Speed: 7.9ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 167.0ms
# Speed: 0.0ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 68.0ms
# Speed: 6.9ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 75.6ms
# Speed: 4.2ms preprocess, 75.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 160.5ms
# Speed: 0.0ms preprocess, 160.5ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.8ms
# Speed: 5.2ms preprocess, 71.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 76.0ms
# Speed: 5.6ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 159.3ms
# Speed: 0.0ms preprocess, 159.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.0ms
# Speed: 0.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 80.9ms
# Speed: 4.5ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 165.0ms
# Speed: 0.0ms preprocess, 165.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 77.9ms
# Speed: 0.0ms preprocess, 77.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 ANPR, 74.6ms
# Speed: 5.9ms preprocess, 74.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.7ms
# Speed: 15.1ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 ANPR, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 car, 143.8ms
# Speed: 2.1ms preprocess, 143.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: LATLIN
#
# 0: 640x480 1 ANPR, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 66.8ms
# Speed: 6.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 145.2ms
# Speed: 6.5ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.9ms
# Speed: 4.9ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 88.9ms
# Speed: 0.0ms preprocess, 88.9ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 car, 176.8ms
# Speed: 2.8ms preprocess, 176.8ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.5ms
# Speed: 0.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZATLIN
#
# 0: 640x480 1 ANPR, 85.7ms
# Speed: 5.5ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 car, 167.5ms
# Speed: 8.7ms preprocess, 167.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: ZLATLIN
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 150.7ms
# Speed: 0.0ms preprocess, 150.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 70.5ms
# Speed: 12.2ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 74.7ms
# Speed: 1.9ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 189.0ms
# Speed: 0.0ms preprocess, 189.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 81.6ms
# Speed: 0.0ms preprocess, 81.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 68.3ms
# Speed: 5.1ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 151.4ms
# Speed: 0.0ms preprocess, 151.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 64.1ms
# Speed: 3.4ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 114.0ms
# Speed: 0.0ms preprocess, 114.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 142.8ms
# Speed: 0.0ms preprocess, 142.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.7ms
# Speed: 3.1ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 134.4ms
# Speed: 3.6ms preprocess, 134.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.5ms
# Speed: 2.8ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 72.0ms
# Speed: 3.3ms preprocess, 72.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLTLIN
#
# 0: 640x480 1 car, 166.2ms
# Speed: 0.0ms preprocess, 166.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLTLIN
#
# 0: 640x480 1 ANPR, 78.7ms
# Speed: 0.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 171.8ms
# Speed: 0.0ms preprocess, 171.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 67.3ms
# Speed: 7.7ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 99.4ms
# Speed: 7.8ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 145.0ms
# Speed: 0.0ms preprocess, 145.0ms inference, 12.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 83.2ms
# Speed: 4.9ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 155.4ms
# Speed: 14.5ms preprocess, 155.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 75.2ms
# Speed: 0.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 76.8ms
# Speed: 0.0ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 159.1ms
# Speed: 8.6ms preprocess, 159.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 80.9ms
# Speed: 0.0ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 70.9ms
# Speed: 0.0ms preprocess, 70.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 1 cat, 154.3ms
# Speed: 0.0ms preprocess, 154.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 76.2ms
# Speed: 0.0ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 ANPR, 121.3ms
# Speed: 0.0ms preprocess, 121.3ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 166.8ms
# Speed: 0.0ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 71.4ms
# Speed: 5.1ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 75.4ms
# Speed: 4.5ms preprocess, 75.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 car, 156.4ms
# Speed: 5.7ms preprocess, 156.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 73.3ms
# Speed: 4.1ms preprocess, 73.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLATLIN
#
# 0: 640x480 1 ANPR, 75.8ms
# Speed: 0.0ms preprocess, 75.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
#
# 0: 640x480 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ANPR, 76.7ms
# Speed: 0.0ms preprocess, 76.7ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 480)
# Detected License Plate: FLHTLIN
