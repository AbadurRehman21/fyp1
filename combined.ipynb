# %%
import importlib
import smoke_detection
importlib.reload(smoke_detection)
from smoke_detection import detect_smoke
import vehicle_detection
importlib.reload(vehicle_detection)
# Out:
# <module 'vehicle_detection' from 'c:\\Users\\Abad\\Desktop\\FYP\\yolo_test\\combine_2\\final_realtime\\vehicle_detection.py'>

# %%
import os
import cv2
import time
import csv
from collections import Counter
from ultralytics import YOLO
import easyocr

# Import existing functions and counters
from license_plate_detection import process_license_plate_frame, license_plate_counts
from smoke_detection import detect_smoke  # assume this function works on any input image (cropped or full)
from vehicle_detection import detect_vehicle

# --- Paths for Output ---
output_dir = r"./output"
os.makedirs(output_dir, exist_ok=True)
csv_file_path = os.path.join(output_dir, "detected_plates.csv")

# --- Track plates saved this session ---
saved_plates_session = set()

def save_plate_csv(plate_text, extra_info="SmokingVehicle"):
    if plate_text in saved_plates_session:
        return

    saved_plates_session.add(plate_text)
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    row = [timestamp, plate_text, extra_info]

    file_exists = os.path.isfile(csv_file_path)
    with open(csv_file_path, mode="a", newline="", encoding="utf-8") as csv_file:
        writer = csv.writer(csv_file)
        if not file_exists:
            writer.writerow(["DateTime", "LicensePlate", "ExtraInfo"])
        writer.writerow(row)
    print(f"Saved new license plate to CSV: {plate_text}")

def process_frame_strategy(frame):
    """
    Process a frame using a step-by-step strategy:
      1. Detect vehicles.
      2. For each vehicle, crop the region and run smoke detection.
      3. If smoke is confirmed, run license plate detection on that vehicle region.
      4. Annotate the full frame with the "smoking vehicle" info and save the license plate to CSV.
    
    Returns:
        Annotated frame.
    """
    output_frame = frame.copy()

    # Detect vehicles in the full frame
    vehicle_detections = detect_vehicle(frame)
    
    # Iterate over each detected vehicle
    for det in vehicle_detections:
        box = det["box"]  # [x1, y1, x2, y2]
        # Crop the region corresponding to the vehicle
        x1, y1, x2, y2 = box
        vehicle_roi = frame[y1:y2, x1:x2]
        
        # Safety check: if the ROI is empty, skip
        if vehicle_roi.size == 0:
            continue
        
        # Run smoke detection on the cropped vehicle ROI.
        # (Assuming detect_smoke can be run on any image; if it returns (smoke_detected, processed_image),
        # adapt accordingly. Here we assume it returns a boolean and a processed image.)
        smoke_detected, _ = detect_smoke(vehicle_roi)
        
        # If the vehicle region shows smoke, run license plate detection on the same region.
        if smoke_detected:
            # Option 1: Run license plate detection on the vehicle ROI.
            lp_roi = process_license_plate_frame(vehicle_roi.copy())
            # Optionally, if process_license_plate_frame returns an annotated image, you could extract
            # the license plate string from the global license_plate_counts (if that's how your module works)
            if license_plate_counts:
                most_common_plate = license_plate_counts.most_common(1)[0][0]
                # Save the license plate to CSV (only once per session)
                save_plate_csv(most_common_plate)
                # Annotate the full frame: Draw the bounding box in red and label it.
                cv2.rectangle(output_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(output_frame, f"vehicle (smoke) - Plate: {most_common_plate}", 
                            (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
            else:
                # If no plate is detected, at least label the vehicle as smoking.
                cv2.rectangle(output_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(output_frame, "vehicle (smoke)", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        else:
            # For vehicles without smoke, you might want to annotate them differently (optional)
            cv2.rectangle(output_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(output_frame, "vehicle", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    return output_frame

def run_detection(source=0):
    """
    Runs the combined strategy on either:
      - Webcam (source=0)
      - Video file (source="video.mp4")
    Saves the resulting video to ./output/predicted_output.avi
    """
    # Clear global counters and session data
    license_plate_counts.clear()
    saved_plates_session.clear()

    cap = cv2.VideoCapture(source)
    if not cap.isOpened():
        print(f"Error: Could not open source: {source}")
        return

    # --- Setup VideoWriter ---
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    if fps == 0 or fps is None:
        fps = 25

# Find next available filename
    i = 1
    while True:
        output_path = os.path.join(output_dir, f"predicted_output{i}.avi")
        if not os.path.exists(output_path):
            break
        i += 1

    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    print(f"Saving output video to: {output_path}")


    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or error reading frame.")
            break

        processed_frame = process_frame_strategy(frame)
        out.write(processed_frame)
        cv2.imshow("Vehicle with Confirmed Smoke Detection", processed_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()


def main():
    # Use 0 for real-time camera, or provide a path like 'input_video.mp4'
    # Example usage:
    # run_detection(0)  # real-time
    run_detection("input/4.mp4")  # video file

if __name__ == "__main__":
    main()
# Out:
# Saving output video to: ./output\predicted_output2.avi
#
# 0: 640x384 1 truck, 99.4ms
# Speed: 6.2ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 70.0ms
# Speed: 1.6ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 107.7ms
# Speed: 2.3ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.4ms
# Speed: 13.1ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 116.8ms
# Speed: 0.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 77.1ms
# Speed: 0.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.6ms
# Speed: 0.0ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 65.7ms
# Speed: 14.9ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 116.1ms
# Speed: 0.0ms preprocess, 116.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 86.8ms
# Speed: 0.0ms preprocess, 86.8ms inference, 12.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 58.3ms
# Speed: 8.2ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 98.4ms
# Speed: 0.0ms preprocess, 98.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 95.7ms
# Speed: 2.3ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 69.2ms
# Speed: 0.0ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 94.7ms
# Speed: 1.6ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 63.7ms
# Speed: 2.9ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 98.5ms
# Speed: 0.0ms preprocess, 98.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 111.8ms
# Speed: 4.6ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 94.2ms
# Speed: 2.1ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.1ms
# Speed: 0.0ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 96.9ms
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.7ms
# Speed: 12.3ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 113.5ms
# Speed: 2.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 113.0ms
# Speed: 3.3ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 110.0ms
# Speed: 3.3ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 96.6ms
# Speed: 2.9ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 71.3ms
# Speed: 0.0ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 109.6ms
# Speed: 2.4ms preprocess, 109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 62.3ms
# Speed: 0.0ms preprocess, 62.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 68.6ms
# Speed: 0.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 110.2ms
# Speed: 4.2ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 52.0ms
# Speed: 13.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 98.7ms
# Speed: 2.0ms preprocess, 98.7ms inference, 13.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 70.4ms
# Speed: 0.0ms preprocess, 70.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 70.2ms
# Speed: 0.0ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.3ms
# Speed: 0.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.7ms
# Speed: 0.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 97.8ms
# Speed: 2.0ms preprocess, 97.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 56.2ms
# Speed: 10.7ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 112.6ms
# Speed: 1.2ms preprocess, 112.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 100.3ms
# Speed: 0.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 105.8ms
# Speed: 3.9ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 94.1ms
# Speed: 1.0ms preprocess, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 59.1ms
# Speed: 6.4ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 99.7ms
# Speed: 2.0ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 56.6ms
# Speed: 12.8ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 98.0ms
# Speed: 5.9ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 66.2ms
# Speed: 0.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 100.9ms
# Speed: 0.0ms preprocess, 100.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 67.6ms
# Speed: 0.0ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 85.9ms
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 102.1ms
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 52.8ms
# Speed: 16.1ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 110.2ms
# Speed: 2.1ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 54.9ms
# Speed: 15.7ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 96.8ms
# Speed: 0.0ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 98.0ms
# Speed: 0.0ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 63.6ms
# Speed: 0.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 94.8ms
# Speed: 0.0ms preprocess, 94.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 67.0ms
# Speed: 10.6ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 110.7ms
# Speed: 2.3ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 107.5ms
# Speed: 6.6ms preprocess, 107.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 63.7ms
# Speed: 1.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 114.7ms
# Speed: 2.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 83.5ms
# Speed: 0.0ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 123.2ms
# Speed: 0.0ms preprocess, 123.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 85.6ms
# Speed: 13.6ms preprocess, 85.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 128.4ms
# Speed: 4.3ms preprocess, 128.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 80.6ms
# Speed: 0.0ms preprocess, 80.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 151.9ms
# Speed: 3.0ms preprocess, 151.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 91.0ms
# Speed: 9.3ms preprocess, 91.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 132.5ms
# Speed: 3.0ms preprocess, 132.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 84.7ms
# Speed: 15.8ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 143.2ms
# Speed: 4.6ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 94.1ms
# Speed: 0.0ms preprocess, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 148.7ms
# Speed: 3.0ms preprocess, 148.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 90.3ms
# Speed: 0.0ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 153.4ms
# Speed: 3.4ms preprocess, 153.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 96.3ms
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 138.9ms
# Speed: 0.0ms preprocess, 138.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 85.8ms
# Speed: 0.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 81.7ms
# Speed: 6.7ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 132.6ms
# Speed: 6.6ms preprocess, 132.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 95.3ms
# Speed: 0.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 148.0ms
# Speed: 4.8ms preprocess, 148.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 82.4ms
# Speed: 15.3ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 148.3ms
# Speed: 0.0ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 92.7ms
# Speed: 0.0ms preprocess, 92.7ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 132.3ms
# Speed: 0.0ms preprocess, 132.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 131.3ms
# Speed: 0.0ms preprocess, 131.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 95.9ms
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 136.2ms
# Speed: 4.9ms preprocess, 136.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 78.0ms
# Speed: 4.1ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 85.2ms
# Speed: 0.0ms preprocess, 85.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 143.4ms
# Speed: 4.6ms preprocess, 143.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 81.8ms
# Speed: 15.6ms preprocess, 81.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 148.6ms
# Speed: 6.7ms preprocess, 148.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 79.8ms
# Speed: 4.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 129.4ms
# Speed: 0.0ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 88.5ms
# Speed: 0.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 truck, 146.9ms
# Speed: 6.3ms preprocess, 146.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 149.7ms
# Speed: 0.0ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 136.4ms
# Speed: 0.0ms preprocess, 136.4ms inference, 12.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 155.2ms
# Speed: 0.0ms preprocess, 155.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 146.2ms
# Speed: 3.5ms preprocess, 146.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 134.5ms
# Speed: 0.0ms preprocess, 134.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.3ms
# Speed: 2.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 137.2ms
# Speed: 0.0ms preprocess, 137.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 129.5ms
# Speed: 2.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 138.1ms
# Speed: 0.0ms preprocess, 138.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 164.3ms
# Speed: 2.0ms preprocess, 164.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 152.6ms
# Speed: 0.0ms preprocess, 152.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 truck, 145.8ms
# Speed: 1.0ms preprocess, 145.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 truck, 146.5ms
# Speed: 2.0ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 truck, 150.3ms
# Speed: 0.0ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 150.5ms
# Speed: 0.0ms preprocess, 150.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 132.5ms
# Speed: 0.0ms preprocess, 132.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.4ms
# Speed: 0.0ms preprocess, 149.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.6ms
# Speed: 4.5ms preprocess, 137.6ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 126.8ms
# Speed: 2.8ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.8ms
# Speed: 0.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 134.1ms
# Speed: 0.0ms preprocess, 134.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 142.9ms
# Speed: 7.0ms preprocess, 142.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.4ms
# Speed: 2.8ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 151.1ms
# Speed: 0.0ms preprocess, 151.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.7ms
# Speed: 2.0ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.8ms
# Speed: 0.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.7ms
# Speed: 0.0ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.6ms
# Speed: 0.0ms preprocess, 129.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.5ms
# Speed: 4.2ms preprocess, 148.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.2ms
# Speed: 0.0ms preprocess, 131.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 142.4ms
# Speed: 2.0ms preprocess, 142.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 138.0ms
# Speed: 0.0ms preprocess, 138.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 144.9ms
# Speed: 2.1ms preprocess, 144.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.5ms
# Speed: 0.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.9ms
# Speed: 2.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.7ms
# Speed: 2.0ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 166.7ms
# Speed: 0.0ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 135.4ms
# Speed: 0.0ms preprocess, 135.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 154.1ms
# Speed: 0.0ms preprocess, 154.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x512 (no detections), 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x384 (no detections), 137.7ms
# Speed: 0.0ms preprocess, 137.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 126.9ms
# Speed: 4.7ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 69.0ms
# Speed: 0.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 129.3ms
# Speed: 5.6ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 129.0ms
# Speed: 3.0ms preprocess, 129.0ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 84.2ms
# Speed: 0.0ms preprocess, 84.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 66.3ms
# Speed: 0.6ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 145.2ms
# Speed: 4.6ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 136.4ms
# Speed: 0.0ms preprocess, 136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 70.4ms
# Speed: 0.0ms preprocess, 70.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 130.9ms
# Speed: 5.6ms preprocess, 130.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 135.8ms
# Speed: 0.0ms preprocess, 135.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 87.0ms
# Speed: 13.7ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 144.2ms
# Speed: 5.5ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x512 (no detections), 86.5ms
# Speed: 0.0ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x384 1 car, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x512 (no detections), 83.6ms
# Speed: 0.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x384 (no detections), 148.2ms
# Speed: 5.5ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 130.0ms
# Speed: 0.0ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.5ms
# Speed: 0.0ms preprocess, 137.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.7ms
# Speed: 0.0ms preprocess, 137.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.2ms
# Speed: 0.0ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.7ms
# Speed: 2.0ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.9ms
# Speed: 2.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.8ms
# Speed: 3.7ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.1ms
# Speed: 3.8ms preprocess, 129.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 131.3ms
# Speed: 2.1ms preprocess, 131.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.4ms
# Speed: 3.8ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 132.9ms
# Speed: 0.0ms preprocess, 132.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 144.7ms
# Speed: 6.5ms preprocess, 144.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 150.0ms
# Speed: 0.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 150.0ms
# Speed: 0.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 143.5ms
# Speed: 3.4ms preprocess, 143.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.7ms
# Speed: 0.0ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 135.6ms
# Speed: 0.0ms preprocess, 135.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 148.5ms
# Speed: 0.0ms preprocess, 148.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 128.6ms
# Speed: 3.0ms preprocess, 128.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 146.1ms
# Speed: 0.0ms preprocess, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.3ms
# Speed: 0.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.5ms
# Speed: 0.0ms preprocess, 129.5ms inference, 16.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 145.8ms
# Speed: 0.0ms preprocess, 145.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 143.4ms
# Speed: 0.0ms preprocess, 143.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.5ms
# Speed: 0.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.4ms
# Speed: 0.0ms preprocess, 129.4ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 131.2ms
# Speed: 2.0ms preprocess, 131.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 130.4ms
# Speed: 3.4ms preprocess, 130.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 134.8ms
# Speed: 0.0ms preprocess, 134.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 147.6ms
# Speed: 2.2ms preprocess, 147.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 147.8ms
# Speed: 2.1ms preprocess, 147.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.8ms
# Speed: 3.0ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 81.9ms
# Speed: 0.0ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 143.6ms
# Speed: 6.0ms preprocess, 143.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 67.2ms
# Speed: 14.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 83.2ms
# Speed: 0.0ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 144.1ms
# Speed: 5.5ms preprocess, 144.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x480 (no detections), 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x384 1 car, 127.3ms
# Speed: 4.7ms preprocess, 127.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 128.6ms
# Speed: 3.3ms preprocess, 128.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 132.2ms
# Speed: 0.0ms preprocess, 132.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 154.8ms
# Speed: 0.0ms preprocess, 154.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 145.4ms
# Speed: 2.3ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 131.1ms
# Speed: 2.0ms preprocess, 131.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 165.7ms
# Speed: 0.0ms preprocess, 165.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 138.8ms
# Speed: 0.0ms preprocess, 138.8ms inference, 11.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.0ms
# Speed: 0.0ms preprocess, 149.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 144.8ms
# Speed: 0.0ms preprocess, 144.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 144.9ms
# Speed: 2.0ms preprocess, 144.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 146.2ms
# Speed: 2.0ms preprocess, 146.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 130.2ms
# Speed: 2.5ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.3ms
# Speed: 4.5ms preprocess, 145.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.2ms
# Speed: 5.0ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 165.3ms
# Speed: 3.4ms preprocess, 165.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.5ms
# Speed: 4.8ms preprocess, 148.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.8ms
# Speed: 3.5ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 sink, 147.5ms
# Speed: 2.0ms preprocess, 147.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 sink, 146.7ms
# Speed: 4.8ms preprocess, 146.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 162.2ms
# Speed: 4.4ms preprocess, 162.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.8ms
# Speed: 3.0ms preprocess, 145.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 122.1ms
# Speed: 0.0ms preprocess, 122.1ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 138.5ms
# Speed: 0.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.7ms
# Speed: 0.0ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.1ms
# Speed: 4.2ms preprocess, 137.1ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 128.2ms
# Speed: 2.0ms preprocess, 128.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 136.5ms
# Speed: 0.0ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.8ms
# Speed: 0.0ms preprocess, 131.8ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 132.9ms
# Speed: 0.0ms preprocess, 132.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.9ms
# Speed: 2.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 134.7ms
# Speed: 0.0ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 135.8ms
# Speed: 4.6ms preprocess, 135.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.0ms
# Speed: 2.6ms preprocess, 129.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.8ms
# Speed: 0.0ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 136.4ms
# Speed: 0.0ms preprocess, 136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x512 (no detections), 79.0ms
# Speed: 0.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x384 1 motorcycle, 145.6ms
# Speed: 2.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 135.2ms
# Speed: 0.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 143.5ms
# Speed: 0.0ms preprocess, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 138.9ms
# Speed: 0.0ms preprocess, 138.9ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 136.2ms
# Speed: 0.0ms preprocess, 136.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 146.8ms
# Speed: 2.0ms preprocess, 146.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bicycle, 129.0ms
# Speed: 2.0ms preprocess, 129.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 bicycle, 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 (no detections), 141.2ms
# Speed: 5.0ms preprocess, 141.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.6ms
# Speed: 3.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 130.7ms
# Speed: 2.0ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.7ms
# Speed: 0.0ms preprocess, 133.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 146.1ms
# Speed: 0.0ms preprocess, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.4ms
# Speed: 4.6ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 162.4ms
# Speed: 3.0ms preprocess, 162.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 147.7ms
# Speed: 5.8ms preprocess, 147.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.8ms
# Speed: 0.0ms preprocess, 137.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 134.9ms
# Speed: 0.0ms preprocess, 134.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 134.0ms
# Speed: 3.8ms preprocess, 134.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.3ms
# Speed: 0.0ms preprocess, 137.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.7ms
# Speed: 0.0ms preprocess, 133.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.4ms
# Speed: 5.2ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.7ms
# Speed: 0.0ms preprocess, 133.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.2ms
# Speed: 5.4ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.1ms
# Speed: 4.0ms preprocess, 129.1ms inference, 15.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.6ms
# Speed: 4.0ms preprocess, 144.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.4ms
# Speed: 4.5ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 135.2ms
# Speed: 0.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.6ms
# Speed: 6.3ms preprocess, 143.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 164.0ms
# Speed: 4.7ms preprocess, 164.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 126.8ms
# Speed: 6.5ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 132.6ms
# Speed: 0.0ms preprocess, 132.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 135.7ms
# Speed: 5.4ms preprocess, 135.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.7ms
# Speed: 4.5ms preprocess, 145.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.2ms
# Speed: 3.4ms preprocess, 131.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.0ms
# Speed: 6.1ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 148.3ms
# Speed: 5.7ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 131.5ms
# Speed: 0.0ms preprocess, 131.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 116.4ms
# Speed: 0.0ms preprocess, 116.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 146.7ms
# Speed: 6.2ms preprocess, 146.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 132.7ms
# Speed: 0.0ms preprocess, 132.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 135.2ms
# ...
#
# 0: 640x384 1 car, 143.6ms
# Speed: 5.8ms preprocess, 143.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.2ms
# Speed: 4.0ms preprocess, 129.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 146.7ms
# Speed: 0.0ms preprocess, 146.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.4ms
# Speed: 0.0ms preprocess, 137.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 140.4ms
# Speed: 0.0ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 129.4ms
# Speed: 4.3ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 96.0ms
# Speed: 0.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 truck, 158.1ms
# Speed: 6.8ms preprocess, 158.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 83.2ms
# Speed: 1.6ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 car, 1 truck, 160.8ms
# Speed: 5.7ms preprocess, 160.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 144.7ms
# Speed: 3.0ms preprocess, 144.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 149.8ms
# Speed: 0.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 truck, 151.0ms
# Speed: 0.0ms preprocess, 151.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 153.8ms
# Speed: 0.0ms preprocess, 153.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 140.7ms
# Speed: 0.0ms preprocess, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 150.0ms
# Speed: 0.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 83.2ms
# Speed: 1.9ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 truck, 137.0ms
# Speed: 0.0ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 85.1ms
# Speed: 15.1ms preprocess, 85.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 truck, 142.1ms
# Speed: 7.9ms preprocess, 142.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 135.8ms
# Speed: 0.0ms preprocess, 135.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 (no detections), 166.7ms
# Speed: 0.0ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.4ms
# Speed: 0.0ms preprocess, 149.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 161.3ms
# Speed: 5.1ms preprocess, 161.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 truck, 143.8ms
# Speed: 3.0ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 88.3ms
# Speed: 0.0ms preprocess, 88.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 truck, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 truck, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 154.8ms
# Speed: 0.0ms preprocess, 154.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 159.8ms
# Speed: 6.7ms preprocess, 159.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 83.2ms
# Speed: 16.9ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 car, 134.8ms
# Speed: 0.0ms preprocess, 134.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 84.0ms
# Speed: 15.8ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 1 car, 131.9ms
# Speed: 0.0ms preprocess, 131.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 137.0ms
# Speed: 0.0ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.2ms
# Speed: 2.0ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 144.5ms
# Speed: 5.5ms preprocess, 144.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 (no detections), 140.1ms
# Speed: 2.0ms preprocess, 140.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 159.3ms
# Speed: 5.5ms preprocess, 159.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 138.1ms
# Speed: 0.0ms preprocess, 138.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.8ms
# Speed: 0.0ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 150.2ms
# Speed: 6.5ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.9ms
# Speed: 0.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 134.5ms
# Speed: 0.0ms preprocess, 134.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.5ms
# Speed: 2.5ms preprocess, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 138.2ms
# Speed: 0.0ms preprocess, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.7ms
# Speed: 0.0ms preprocess, 133.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 150.8ms
# Speed: 7.1ms preprocess, 150.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 128.1ms
# Speed: 5.2ms preprocess, 128.1ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 130.2ms
# Speed: 2.0ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 132.4ms
# Speed: 4.6ms preprocess, 132.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 141.6ms
# Speed: 4.0ms preprocess, 141.6ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.0ms
# Speed: 3.0ms preprocess, 145.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 145.3ms
# Speed: 4.9ms preprocess, 145.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 132.3ms
# Speed: 0.0ms preprocess, 132.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 137.4ms
# Speed: 0.0ms preprocess, 137.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.4ms
# Speed: 5.6ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 147.7ms
# Speed: 2.4ms preprocess, 147.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.4ms
# Speed: 6.8ms preprocess, 143.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.8ms
# Speed: 6.2ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 113.8ms
# Speed: 2.0ms preprocess, 113.8ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.3ms
# Speed: 5.3ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.9ms
# Speed: 4.0ms preprocess, 143.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 136.9ms
# Speed: 0.0ms preprocess, 136.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 128.0ms
# Speed: 4.8ms preprocess, 128.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.5ms
# Speed: 4.8ms preprocess, 145.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 128.1ms
# Speed: 2.9ms preprocess, 128.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.6ms
# Speed: 0.0ms preprocess, 133.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 146.0ms
# Speed: 3.0ms preprocess, 146.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.8ms
# Speed: 3.6ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 116.8ms
# Speed: 0.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 130.5ms
# Speed: 0.0ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 130.2ms
# Speed: 0.0ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.4ms
# Speed: 2.9ms preprocess, 148.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 165.5ms
# Speed: 5.9ms preprocess, 165.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 160.1ms
# Speed: 6.3ms preprocess, 160.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 162.5ms
# Speed: 2.0ms preprocess, 162.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 145.2ms
# Speed: 4.2ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 150.0ms
# Speed: 4.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 128.7ms
# Speed: 2.1ms preprocess, 128.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.1ms
# Speed: 2.0ms preprocess, 131.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 144.0ms
# Speed: 5.9ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 129.3ms
# Speed: 3.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 130.3ms
# Speed: 2.0ms preprocess, 130.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 179.4ms
# Speed: 2.7ms preprocess, 179.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 161.5ms
# Speed: 5.3ms preprocess, 161.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 161.6ms
# Speed: 0.0ms preprocess, 161.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 161.3ms
# Speed: 5.2ms preprocess, 161.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x576 (no detections), 106.3ms
# Speed: 0.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x384 (no detections), 164.6ms
# Speed: 4.7ms preprocess, 164.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 133.5ms
# Speed: 0.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 130.2ms
# Speed: 0.0ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 car, 145.9ms
# Speed: 6.7ms preprocess, 145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x608 (no detections), 87.1ms
# Speed: 13.8ms preprocess, 87.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x384 1 car, 145.0ms
# Speed: 4.8ms preprocess, 145.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 146.1ms
# Speed: 3.9ms preprocess, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 137.0ms
# Speed: 0.0ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 136.8ms
# Speed: 0.0ms preprocess, 136.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 138.2ms
# Speed: 0.0ms preprocess, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# End of video or error reading frame.
